# %% [markdown]
# <a href="https://colab.research.google.com/github/InesParis/2048_Game/blob/main/gan_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Implementing GAN in PyTorch: Full Example

# %% [markdown]
# ## Setup Environment
# import torch
# import torch.nn as nn
# import torch.optim as optim
# from torchvision import datasets, transforms, utils
# from torch.utils.data import DataLoader
# import matplotlib.pyplot as plt
# import numpy as np

# %%
import torch # import torch module. This is where torch.device, torch.cuda etc comes from

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation
# transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
# train_data = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
# train_loader = DataLoader(train_data, batch_size=128, shuffle=True)

# %% [markdown]
# ## Generator
# class Generator(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.net = nn.Sequential(
#             nn.Linear(100, 256),
#             nn.ReLU(),
#             nn.Linear(256, 512),
#             nn.ReLU(),
#             nn.Linear(512, 28*28),
#             nn.Tanh()
#         )
#     def forward(self, x):
#         return self.net(x).view(-1, 1, 28, 28)

# %% [markdown]
# ## Discriminator
# class Discriminator(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.net = nn.Sequential(
#             nn.Linear(28*28, 512),
#             nn.LeakyReLU(0.2),
#             nn.Linear(512, 256),
#             nn.LeakyReLU(0.2),
#             nn.Linear(256, 1),
#             nn.Sigmoid()
#         )
#     def forward(self, x):
#         return self.net(x.view(-1, 28*28))

# %%
import torch.nn as nn

class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(100, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, 28*28),
            nn.Tanh()
        )
    def forward(self, x):
        return self.net(x).view(-1, 1, 28, 28)

class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )
    def forward(self, x):
        return self.net(x.view(-1, 28*28))

# %%
import torch.optim as optim # Import the optim module from torch

G = Generator().to(device)
D = Discriminator().to(device)
criterion = nn.BCELoss()
opt_G = optim.Adam(G.parameters(), lr=0.0002)
opt_D = optim.Adam(D.parameters(), lr=0.0002)

# %% [markdown]
# ## Training Loop
# losses_G = []
# losses_D = []

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, SubsetRandomSampler
import numpy as np


# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

# Load the MNIST dataset
train_data = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
dataset_size = len(train_data)
indices = list(range(dataset_size))
split = int(np.floor(0.1 * dataset_size))  # Use 10% of data
np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]
train_sampler = SubsetRandomSampler(train_indices)
# Create a DataLoader for the training data
train_loader = DataLoader(train_data, batch_size=64,  sampler=train_sampler)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 16.1MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 493kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.47MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.22MB/s]

# %%
for epoch in range(30):
    for i, (real, _) in enumerate(train_loader):
        real = real.to(device)
        bs = real.size(0)
        label_real = torch.ones(bs, 1).to(device)
        label_fake = torch.zeros(bs, 1).to(device)

# %% [markdown]
#         # Train Discriminator
#         opt_D.zero_grad()
#         pred_real = D(real)
#         loss_real = criterion(pred_real, label_real)

# %%
        noise = torch.randn(bs, 100).to(device)
        fake = G(noise)
        pred_fake = D(fake.detach())
        loss_fake = criterion(pred_fake, label_fake)

# %% [markdown]
#         # Train Generator
#         opt_G.zero_grad()
#         pred = D(fake)
#         loss_G = criterion(pred, label_real)
#         loss_G.backward()
#         opt_G.step()

# %% [markdown]
# In this section the code is trainning the GAN this process can take up to more than an hour, so just hit run and take a deserved break and come back to check it from time to time (This is algo part of the AI process) the time will depend on your computer and on which of the different platforms you are running the notebook.

# %%
for epoch in range(2):
    for i, (real, _) in enumerate(train_loader):
        real = real.to(device)
        bs = real.size(0)
        label_real = torch.ones(bs, 1).to(device)
        label_fake = torch.zeros(bs, 1).to(device)

        # Train Discriminator
        opt_D.zero_grad()

        # Calculate loss_real
        pred_real = D(real)
        loss_real = criterion(pred_real, label_real)

        noise = torch.randn(bs, 100).to(device)
        fake = G(noise)
        pred_fake = D(fake.detach())
        loss_fake = criterion(pred_fake, label_fake)

        loss_D = loss_real + loss_fake
        loss_D.backward()
        opt_D.step()

        # Train Generator
        opt_G.zero_grad()
        pred = D(fake)
        loss_G = criterion(pred, label_real)
        loss_G.backward()
        opt_G.step()
        # Initialize losses_D and losses_G as empty lists before the training loop
        losses_D = []
        losses_G = []
        for epoch in range(2):
            for i, (real, _) in enumerate(train_loader):
        # ... (training loop code) ...

              losses_D.append(loss_D.item())
            losses_G.append(loss_G.item())
            print(f'Epoch {epoch+1}, Loss_D: {loss_D.item():.4f}, Loss_G: {loss_G.item():.4f}')


    losses_D.append(loss_D.item())
    losses_G.append(loss_G.item())
    print(f'Epoch {epoch+1}, Loss_D: {loss_D.item():.4f}, Loss_G: {loss_G.item():.4f}')
# Out:
# Epoch 1, Loss_D: 0.9505, Loss_G: 0.6717
# Epoch 2, Loss_D: 0.9505, Loss_G: 0.6717
# Epoch 1, Loss_D: 0.8938, Loss_G: 0.6559
# Epoch 2, Loss_D: 0.8938, Loss_G: 0.6559
# Epoch 1, Loss_D: 0.8558, Loss_G: 0.6378
# Epoch 2, Loss_D: 0.8558, Loss_G: 0.6378
# Epoch 1, Loss_D: 0.8445, Loss_G: 0.6191
# Epoch 2, Loss_D: 0.8445, Loss_G: 0.6191
# Epoch 1, Loss_D: 0.8537, Loss_G: 0.5950
# Epoch 2, Loss_D: 0.8537, Loss_G: 0.5950
# Epoch 1, Loss_D: 0.8636, Loss_G: 0.5761
# Epoch 2, Loss_D: 0.8636, Loss_G: 0.5761
# Epoch 1, Loss_D: 0.8920, Loss_G: 0.5508
# Epoch 2, Loss_D: 0.8920, Loss_G: 0.5508
# Epoch 1, Loss_D: 0.9218, Loss_G: 0.5318
# Epoch 2, Loss_D: 0.9218, Loss_G: 0.5318
# Epoch 1, Loss_D: 0.9470, Loss_G: 0.5189
# Epoch 2, Loss_D: 0.9470, Loss_G: 0.5189
# Epoch 1, Loss_D: 0.9813, Loss_G: 0.5003
# Epoch 2, Loss_D: 0.9813, Loss_G: 0.5003
# Epoch 1, Loss_D: 1.0104, Loss_G: 0.4895
# Epoch 2, Loss_D: 1.0104, Loss_G: 0.4895
# Epoch 1, Loss_D: 1.0415, Loss_G: 0.4790
# Epoch 2, Loss_D: 1.0415, Loss_G: 0.4790
# Epoch 1, Loss_D: 1.0415, Loss_G: 0.4863
# Epoch 2, Loss_D: 1.0415, Loss_G: 0.4863
# Epoch 1, Loss_D: 1.0474, Loss_G: 0.4931
# Epoch 2, Loss_D: 1.0474, Loss_G: 0.4931
# Epoch 1, Loss_D: 1.0335, Loss_G: 0.5110
# Epoch 2, Loss_D: 1.0335, Loss_G: 0.5110
# Epoch 1, Loss_D: 1.0149, Loss_G: 0.5367
# Epoch 2, Loss_D: 1.0149, Loss_G: 0.5367
# Epoch 1, Loss_D: 0.9717, Loss_G: 0.5775
# Epoch 2, Loss_D: 0.9717, Loss_G: 0.5775
# Epoch 1, Loss_D: 0.9330, Loss_G: 0.6247
# Epoch 2, Loss_D: 0.9330, Loss_G: 0.6247
# Epoch 1, Loss_D: 0.8929, Loss_G: 0.6834
# Epoch 2, Loss_D: 0.8929, Loss_G: 0.6834
# Epoch 1, Loss_D: 0.8593, Loss_G: 0.7583
# Epoch 2, Loss_D: 0.8593, Loss_G: 0.7583
# Epoch 1, Loss_D: 0.8225, Loss_G: 0.8364
# Epoch 2, Loss_D: 0.8225, Loss_G: 0.8364
# Epoch 1, Loss_D: 0.8074, Loss_G: 0.9208
# Epoch 2, Loss_D: 0.8074, Loss_G: 0.9208
# Epoch 1, Loss_D: 0.8151, Loss_G: 0.9900
# Epoch 2, Loss_D: 0.8151, Loss_G: 0.9900
# Epoch 1, Loss_D: 0.8144, Loss_G: 1.0291
# Epoch 2, Loss_D: 0.8144, Loss_G: 1.0291
# Epoch 1, Loss_D: 0.8434, Loss_G: 1.0259
# Epoch 2, Loss_D: 0.8434, Loss_G: 1.0259
# Epoch 1, Loss_D: 0.8522, Loss_G: 0.9675
# Epoch 2, Loss_D: 0.8522, Loss_G: 0.9675
# Epoch 1, Loss_D: 0.8676, Loss_G: 0.8866
# Epoch 2, Loss_D: 0.8676, Loss_G: 0.8866
# Epoch 1, Loss_D: 0.9346, Loss_G: 0.7759
# Epoch 2, Loss_D: 0.9346, Loss_G: 0.7759
# Epoch 1, Loss_D: 1.0058, Loss_G: 0.6910
# Epoch 2, Loss_D: 1.0058, Loss_G: 0.6910
# Epoch 1, Loss_D: 1.0978, Loss_G: 0.6223
# Epoch 2, Loss_D: 1.0978, Loss_G: 0.6223
# Epoch 1, Loss_D: 1.1602, Loss_G: 0.5900
# Epoch 2, Loss_D: 1.1602, Loss_G: 0.5900
# Epoch 1, Loss_D: 1.2815, Loss_G: 0.5593
# Epoch 2, Loss_D: 1.2815, Loss_G: 0.5593
# Epoch 1, Loss_D: 1.3594, Loss_G: 0.5594
# Epoch 2, Loss_D: 1.3594, Loss_G: 0.5594
# Epoch 1, Loss_D: 1.4623, Loss_G: 0.5569
# Epoch 2, Loss_D: 1.4623, Loss_G: 0.5569
# Epoch 1, Loss_D: 1.5307, Loss_G: 0.5492
# Epoch 2, Loss_D: 1.5307, Loss_G: 0.5492
# Epoch 1, Loss_D: 1.5715, Loss_G: 0.5437
# Epoch 2, Loss_D: 1.5715, Loss_G: 0.5437
# Epoch 1, Loss_D: 1.6535, Loss_G: 0.5298
# Epoch 2, Loss_D: 1.6535, Loss_G: 0.5298
# Epoch 1, Loss_D: 1.6157, Loss_G: 0.5184
# Epoch 2, Loss_D: 1.6157, Loss_G: 0.5184
# Epoch 1, Loss_D: 1.5860, Loss_G: 0.5220
# Epoch 2, Loss_D: 1.5860, Loss_G: 0.5220
# Epoch 1, Loss_D: 1.6054, Loss_G: 0.5385
# Epoch 2, Loss_D: 1.6054, Loss_G: 0.5385
# Epoch 1, Loss_D: 1.4966, Loss_G: 0.5826
# Epoch 2, Loss_D: 1.4966, Loss_G: 0.5826
# Epoch 1, Loss_D: 1.3887, Loss_G: 0.6458
# Epoch 2, Loss_D: 1.3887, Loss_G: 0.6458
# Epoch 1, Loss_D: 1.2897, Loss_G: 0.7293
# Epoch 2, Loss_D: 1.2897, Loss_G: 0.7293
# Epoch 1, Loss_D: 1.1538, Loss_G: 0.8481
# Epoch 2, Loss_D: 1.1538, Loss_G: 0.8481
# Epoch 1, Loss_D: 1.0305, Loss_G: 0.9834
# Epoch 2, Loss_D: 1.0305, Loss_G: 0.9834
# Epoch 1, Loss_D: 0.9008, Loss_G: 1.1250
# Epoch 2, Loss_D: 0.9008, Loss_G: 1.1250
# Epoch 1, Loss_D: 0.7786, Loss_G: 1.2953
# Epoch 2, Loss_D: 0.7786, Loss_G: 1.2953
# Epoch 1, Loss_D: 0.6935, Loss_G: 1.4384
# Epoch 2, Loss_D: 0.6935, Loss_G: 1.4384
# Epoch 1, Loss_D: 0.5984, Loss_G: 1.5902
# Epoch 2, Loss_D: 0.5984, Loss_G: 1.5902
# Epoch 1, Loss_D: 0.5374, Loss_G: 1.6868
# Epoch 2, Loss_D: 0.5374, Loss_G: 1.6868
# Epoch 1, Loss_D: 0.4432, Loss_G: 1.8427
# Epoch 2, Loss_D: 0.4432, Loss_G: 1.8427
# Epoch 1, Loss_D: 0.4138, Loss_G: 1.9099
# Epoch 2, Loss_D: 0.4138, Loss_G: 1.9099
# Epoch 1, Loss_D: 0.3639, Loss_G: 2.0179
# Epoch 2, Loss_D: 0.3639, Loss_G: 2.0179
# Epoch 1, Loss_D: 0.3309, Loss_G: 2.1270
# Epoch 2, Loss_D: 0.3309, Loss_G: 2.1270
# Epoch 1, Loss_D: 0.3067, Loss_G: 2.2133
# Epoch 2, Loss_D: 0.3067, Loss_G: 2.2133
# Epoch 1, Loss_D: 0.2891, Loss_G: 2.2978
# Epoch 2, Loss_D: 0.2891, Loss_G: 2.2978
# Epoch 1, Loss_D: 0.2994, Loss_G: 2.3168
# Epoch 2, Loss_D: 0.2994, Loss_G: 2.3168
# Epoch 1, Loss_D: 0.2742, Loss_G: 2.3919
# Epoch 2, Loss_D: 0.2742, Loss_G: 2.3919
# Epoch 1, Loss_D: 0.2811, Loss_G: 2.4115
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-39cdefac4aee> in <cell line: 0>()
#      32         losses_G = []
#      33         for epoch in range(2):
# ---> 34             for i, (real, _) in enumerate(train_loader):
#      35         # ... (training loop code) ...
#      36
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     706                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707                 self._reset()  # type: ignore[call-arg]
# --> 708             data = self._next_data()
#     709             self._num_yielded += 1
#     710             if (
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     762     def _next_data(self):
#     763         index = self._next_index()  # may raise StopIteration
# --> 764         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765         if self._pin_memory:
#     766             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#     144
#     145         if self.transform is not None:
# --> 146             img = self.transform(img)
#     147
#     148         if self.target_transform is not None:
#
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#     135             Tensor: Converted image.
#     136         """
# --> 137         return F.to_tensor(pic)
#     138
#     139     def __repr__(self) -> str:
#
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/functional.py in to_tensor(pic)
#     166     # handle PIL Image
#     167     mode_to_nptype = {"I": np.int32, "I;16" if sys.byteorder == "little" else "I;16B": np.int16, "F": np.float32}
# --> 168     img = torch.from_numpy(np.array(pic, mode_to_nptype.get(pic.mode, np.uint8), copy=True))
#     169
#     170     if pic.mode == "1":
#
# KeyboardInterrupt:

# %%
    losses_D.append(loss_D.item())
    losses_G.append(loss_G.item())
    print(f'Epoch {epoch+1}, Loss_D: {loss_D.item():.4f}, Loss_G: {loss_G.item():.4f}')
# Out:
# Epoch 2, Loss_D: 0.2811, Loss_G: 2.4115

# %% [markdown]
# ## Evaluation
# def show_samples():
#     with torch.no_grad():
#         noise = torch.randn(16, 100).to(device)
#         samples = G(noise).cpu()
#         grid = utils.make_grid(samples, nrow=4, normalize=True)
#         plt.figure(figsize=(5,5))
#         plt.imshow(np.transpose(grid, (1,2,0)))
#         plt.axis('off')
#         plt.show()

# %%
from torchvision import utils
import matplotlib.pyplot as plt
import numpy as np
import torch # Ensure torch is imported

# Evaluation
def show_samples():
    with torch.no_grad():
        noise = torch.randn(16, 100).to(device)
        samples = G(noise).cpu()
        grid = utils.make_grid(samples, nrow=4, normalize=True)
        plt.figure(figsize=(5,5))
        plt.imshow(np.transpose(grid, (1,2,0)))
        plt.axis('off')
        plt.show()

# After defining the function, you can call it
show_samples()

# Loss Plot
# Make sure these are also in a code cell to be executed
plt.plot(losses_D, label='Discriminator')
plt.plot(losses_G, label='Generator')
plt.legend()
plt.title('Loss Curves')
plt.show()

# %% [markdown]
# ## Loss Plot
# plt.plot(losses_D, label='Discriminator')
# plt.plot(losses_G, label='Generator')
# plt.legend()
# plt.title('Loss Curves')
# plt.show()
